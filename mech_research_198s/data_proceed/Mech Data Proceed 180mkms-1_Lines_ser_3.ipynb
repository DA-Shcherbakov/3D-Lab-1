# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from io import StringIO
import math
import os
plt.close('all')

#LP21_2ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_2_series/2021-11-24T18-44-13-LP21-8_Lines_180mkmps_0.8mkm_2series (All).data.txt",delimiter='\t')
#LP19_2ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_2_series/2021-11-24T18-48-47-LP21-8_Lines_180mkmps_0.8mkm_2series (All).data.txt",delimiter='\t')
#LP17_2ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_2_series/2021-11-24T18-50-20-LP21-8_Lines_180mkmps_0.8mkm_2series (All).data.txt",delimiter='\t') ##bad Data
LP21_3ser_1F = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/Forward_2021-11-24T19-00-44-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
LP21_3ser_2R = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/Relax_2021-11-24T19-00-44-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
LP21_3ser_3B = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/Backward_2021-11-24T19-00-44-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
LP19_3ser_1F = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/Forward_2021-11-24T19-05-21-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
LP19_3ser_2R = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/Relax_2021-11-24T19-05-21-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
LP19_3ser_3B = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/Backward_2021-11-24T19-05-21-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
LP17_3ser_1F = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/Forward_2021-11-24T19-09-57-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
LP17_3ser_2R = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/Relax_2021-11-24T19-09-57-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
LP17_3ser_3B = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/Backward_2021-11-24T19-09-57-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
#LP15_3ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/2021-11-24T19-15-22-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
# LP13_3ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/2021-11-24T19-20-02-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
# LP11_3ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/2021-11-24T19-24-36-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
# LP9_3ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/2021-11-24T19-29-13-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
# LP7_3ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/2021-11-24T19-33-50-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
# LP71_3ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/2021-11-24T19-38-27-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
# LP74_3ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/2021-11-24T19-43-04-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
# LP77_3ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/2021-11-24T19-47-41-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')
# LP8_3ser = np.loadtxt("Move_clbr_flat_punch_Lines_180mkmps_3_series/2021-11-24T19-53-53-LP21-8_Lines_180mkmps_0.8mkm_3series (All).data.txt",delimiter='\t')

# %%
tmp = %who_ls
i = 0
sample_list_tmp = []
while tmp[i][0] == 'L':
    sample_list_tmp.append(tmp[i])
    i+=1
# %whos
sample_list = sample_list_tmp [2::3]
print(sample_list)

f = open('path.txt','r')
path_fig = f.readline().strip()
f.close()

f = open('config_proceed.txt','r')
dS_modale = int(f.readline().strip())
f.close()
sample_list
# Out:
# Variable          Type       Data/Info
# --------------------------------------
# LP17_3ser_1F      ndarray    9796x2: 19592 elems, type `float64`, 156736 bytes (153.0625 kb)
# LP17_3ser_2R      ndarray    926x2: 1852 elems, type `float64`, 14816 bytes
# LP17_3ser_3B      ndarray    5938x2: 11876 elems, type `float64`, 95008 bytes
# LP19_3ser_1F      ndarray    9871x2: 19742 elems, type `float64`, 157936 bytes (154.234375 kb)
# LP19_3ser_2R      ndarray    926x2: 1852 elems, type `float64`, 14816 bytes
# LP19_3ser_3B      ndarray    4935x2: 9870 elems, type `float64`, 78960 bytes
# LP21_3ser_1F      ndarray    9360x2: 18720 elems, type `float64`, 149760 bytes (146.25 kb)
# LP21_3ser_2R      ndarray    926x2: 1852 elems, type `float64`, 14816 bytes
# LP21_3ser_3B      ndarray    2775x2: 5550 elems, type `float64`, 44400 bytes
# StringIO          type       <class '_io.StringIO'>
# i                 int        9
# math              module     <module 'math' from '/hom<...>-38-x86_64-linux-gnu.so'>
# np                module     <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# os                module     <module 'os' from '/home/<...>da3/lib/python3.8/os.py'>
# pd                module     <module 'pandas' from '/h<...>ages/pandas/__init__.py'>
# plt               module     <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# sample_list_tmp   list       n=9
# sns               module     <module 'seaborn' from '/<...>ges/seaborn/__init__.py'>
# tmp               list       n=16
# ['LP17_3ser_3B', 'LP19_3ser_3B', 'LP21_3ser_3B']
# ['LP17_3ser_3B', 'LP19_3ser_3B', 'LP21_3ser_3B']

# %%
for name in sample_list_tmp:
    np_tmp = globals().get(name)
    if name[-1] !='B':

    #     print(np_tmp[:,0])
        plt.plot(np_tmp[:,0],np_tmp[:,1])
    else:
        plt.plot(np_tmp[:,0],np_tmp[:,1])
        plt.title(name[:-3])
        plt.show()
#plt.legend()

# %%
def find_limit(np_tmp):
    down_limit =0
#     up_limit = 0
    count_d = 0
#     count_up = 0
    
    df_limit = 0.3
    step = 30
#     step_dt = 0.2
    i = 1
    len_np_tmp = len(np_tmp)
#    print(len_DF)
#     print('h,nm',(np_tmp[i,0], np_tmp[2,0]),' F,mkmN',(np_tmp[i,1],np_tmp[i+step,1]))
    while i < len_np_tmp/2:
        
        i_new = i + step
    
#         print('h,nm',(np_tmp[i,0], np_tmp[i_new,0]),' F,mkmN',(np_tmp[i,1],np_tmp[i_new,1]))
        
        df_d = (np_tmp[i,1] - np_tmp[i_new,1])/(np_tmp[i,0] - np_tmp[i_new,0])

#         df_up = (np_tmp[-i][1] - np_tmp[-(i_new)][1])/(np_tmp[-i][0] - np_tmp[-(i_new)][0])
        
#         print(df_d,df_up)

        if abs(df_d) < df_limit and count_d < 10:
            down_limit = i
            count_d = 0
        else:
            count_d += 1

#         if abs(df_up) < df_limit and count_up < 10:
#             up_limit = i
#             count_up = 0
#         else:
#             count_up += 1
              
        i+=step
#     up_limit_tmp = -up_limit
    print(down_limit,np_tmp[down_limit,0])
#     counter = 0
    if down_limit != 0:
        for i in range(down_limit):
            np_tmp = np.delete(np_tmp,(0), axis = 0)
#             counter +=1
#     print('I have deleted that %d!'%(counter))
        
    len_np_tmp -= down_limit 
    
#     if up_limit != 0:
#         for i in range(up_limit):
#             np_tmp = np.delete(np_tmp,(-1), axis = 0)
    
    #print(len(DF),down_limit,up_limit)
    
    
    
    
    #len_DF = len(DF)
    #df_limit = 10000
    #down_limit =0
    #up_limit = 0
    #count_up = 0
    #count_d = 0
    #i = 0
    #part = 0.35
    #while i < len_DF*part:
    
        #df_d = (DF[i][3] - DF[i_new][3])/

        #df_up = (DF[-i][3] - DF[-(i_new)][3])/
        
   #     if (DF[i][3] - DF[i_new][3])==0:
             #down_limit = i
     #       count_d = 0
        #elif abs((DF[i][2] - DF[i_new][2])/(DF[i][3] - DF[i_new][3])) > df_limit and count_d < 10:
         #   print((DF[i][2] - DF[i_new][2])/(DF[i][3] - DF[i_new][3]))
          #  down_limit = i
           # count_d = 0
        #else:
         #   count_d += 1

#        if (DF[-i][3] - DF[-(i_new)][3])==0:
#            up_limit = i
#            count_up = 0
#        elif abs((DF[-i][2] - DF[-(i_new)][2])/(DF[-i][3] - DF[-(i_new)][3])) > df_limit and count_up < 10:
#            print((DF[-i][2] - DF[-(i_new)][2])/(DF[i][3] - DF[-(i_new)][3]))
#            up_limit = i
#            count_up = 0
#        else:
#            count_up += 1
              
#        i+=step
    
#    for i in range(down_limit):
#        DF = np_tmp.delete(DF,(0), axis = 0)
        
#    len_DF -= down_limit 
    
#    for i in range(up_limit):
#        DF = np_tmp.delete(DF,(-1), axis = 0)
        
#    print(len(DF),down_limit,up_limit)
#    print(DF.shape)
    return np_tmp

# %%
def join_data(frame):
#     print(id(np.empty((1,2))))
    new_np_tmp = np.empty((1,2))
#     print(id(new_np_tmp))
    for name in sample_list_tmp:
        
        np_tmp = globals().get(name)
#         print(name,id(np_tmp))
#         new_np_tmp = np_tmp.copy()
        if name[-1] != 'B':

            new_np_tmp = np.vstack((new_np_tmp,np_tmp))
#             print('new_np_tmp',id(new_np_tmp),len(new_np_tmp))
        #i = 1
        #dlina = len(DF_tmp)
        #while i < dlina:
        #    new_DF_tmp = np.vstack([new_DF_tmp, DF_tmp[]])
#            i+=1000
        
        #new_DF_tmp.rename(columns = {'F,mkmN': name}, inplace = True)
        else:
            new_np_tmp = np.vstack((new_np_tmp,np_tmp))
            frame.append(new_np_tmp)
#             print('new_np_tmp',id(new_np_tmp),len(new_np_tmp))
            new_np_tmp = new_np_tmp[0:0,:]
#         print('new_np_tmp',id(new_np_tmp),new_np_tmp)

# %%
frame = []

join_data(frame)

# %%
for k in range(len(frame)):
    np_tmp = frame[k]
    #DF_tmp_df = pd.DataFrame(data=DF_tmp, index=np.array(range(len(DF_tmp))),columns=range(5))
    #DF_tmp_df.plot(x=0,y=3)
#     print(np_tmp.shape,id(np_tmp),np_tmp[0,0])
    frame[k] = find_limit(np_tmp)
    min_value = frame[k][0,0]
#     print(min_value)
    frame[k][:,0] = frame[k][:,0] - min_value
    plt.plot(frame[k][:,0],frame[k][:,1],label = sample_list_tmp[3*k][:4])
plt.legend()
plt.ylabel('F ($\mu$m)')
plt.xlabel('h (nm)')
path = os.path.join(path_fig,'F_h_all_180mkmps_Lines_ser_3.pdf')
plt.savefig(path)

plt.show()
# Out:
# 871 921.109375
# 451 770.30078125
# 0 0.0

# %%
# %who_ls
# Out:
# ['LP17_3ser_1F',
#  'LP17_3ser_2R',
#  'LP17_3ser_3B',
#  'LP19_3ser_1F',
#  'LP19_3ser_2R',
#  'LP19_3ser_3B',
#  'LP21_3ser_1F',
#  'LP21_3ser_2R',
#  'LP21_3ser_3B',
#  'StringIO',
#  'dS_modale',
#  'f',
#  'find_limit',
#  'frame',
#  'i',
#  'join_data',
#  'k',
#  'math',
#  'min_value',
#  'name',
#  'np',
#  'np_tmp',
#  'os',
#  'path',
#  'path_fig',
#  'pd',
#  'plt',
#  'sample_list',
#  'sample_list_tmp',
#  'sns',
#  'tmp']

# %%
def reader_of_LP(sample_list):
    list_LP = []
    for name in sample_list:
        len_name = len(name)
        str_list = list(name)
        str_tmp = []
        i = 0
        j = 0
        while name[i] !='P':
            i+=1
        i+=1
        while name[i+j] !="_":
            str_tmp +=str_list[i+j]
            j+=1
            
        tmp = int(''.join(str_tmp))
        if tmp < 30:
            tmp = float(tmp/2)
        else:
            tmp = float(tmp/10/2)
            
        list_LP.append(tmp)
    return list_LP

# %%
list_LP = reader_of_LP(sample_list)
list_LP
# Out:
# [8.5, 9.5, 10.5]

# %%
def calc_Er(np_tmp,dS_modale):
    
#     name = sample_list[k]
#     print(np_tmp,name)
#     normirovka(np_tmp,name)
    start = 0
    #print(start,np_tmp['h,nm'][start])
    finish = start
    #print(start,np_tmp['h,nm'][finish+1])
    dS_real = 0 
    #print(start)
    while abs(dS_real) < dS_modale:
        
        finish +=1
        dS_real = np_tmp[finish][0] - np_tmp[start][0]
        #print(dS_real)
    
    NP = np.array([0,0])
    for i in range(start,finish+1):
        #print([np_tmp['h,nm'][i], np_tmp[sample_list[k]][i]])
        NP = np.vstack([NP, np_tmp[i]])
    NP = np.delete(NP,(0),axis = 0)
    #print(np_tmp[:,0])
    plt.plot(NP[:,0], NP[:,1])
    
    x_tmp = np.vstack([NP[:,0], np.ones(len(NP[:,0]))]).T
    #x_tmp = np_tmp[:,0].T
    #print(x_tmp)
    Er, tmp =np.linalg.lstsq(x_tmp,NP[:,1],rcond=None)[0] 

    plt.plot(x_tmp,x_tmp*Er + tmp,'r',label="Fitted line")
#     plt.xlim([2000-dS_modale, 2050])
    plt.ylim([0,20000])
    #Er = (np_tmp[sample_list[k]][finish] - np_tmp[sample_list[k]][start])/(dS_real)
    #np_tmp[start-50:finish].plot(x='h,nm',y=sample_list[k])
    #print(Er)
    return abs(Er)
    
# def find_reload(np_tmp):
    
#     len_np_tmp = len(np_tmp)
#     i = int(len_np_tmp*0.2)
#     step = 1
#     np_tmp_limit = 15
#     count = 0
#     #print(i,np_tmp['h,nm'])
#     np_tmp = int((np_tmp['h,nm'][5+i] - np_tmp['h,nm'][i])/(np_tmp['t,s'][i+5] - np_tmp['t,s'][i]))
#     #print(np_tmp)
#     while i < len_np_tmp :
#         i+=step
#         np_tmp = int((np_tmp['h,nm'][i+5] - np_tmp['h,nm'][i])/(np_tmp['t,s'][i+5] - np_tmp['t,s'][i]))
#         #print(np_tmp,count,i)
#         if np_tmp >= 0 and count < 3:
#             count = 0
#         elif count >= 3 and abs(np_tmp) > np_tmp_limit:
#             #print(i)
#             return i
#         else:
#             count+=1
#         #print(np_tmp)
        
#     #print(i)
#     #print(np_tmp)
#     #np_tmp.plot(x='t,s',y='h,nm')
#     #return i
    
# def normirovka(np_tmp,name):
    
#     j = 0
#     ref_tmp = min(np_tmp[name][:len(np_tmp)-1])
#     while j < len(np_tmp):


#         tmp = np_tmp[name][j]
#         np_tmp[name][j] = tmp - ref_tmp
#         j+=1

# %%
list_Er = []
for name in sample_list:
    np_tmp = globals().get(name)
    df_dh = calc_Er(np_tmp,dS_modale)
    Area = 625 *0.25 * math.pi
    t = 10
    Er = t*df_dh/Area
    list_Er.append(Er)
    #calc_Er(DF_tmp,k)
list_Er
# Out:
# [0.21859924876593698, 0.1644788404076393, 0.1549019350658709]

# %%
import pylab
Er_LP = np.vstack((list_LP, list_Er))
pylab.subplot(121)
pylab.scatter(Er_LP[0], Er_LP[1], label= 'V = 180 $\mu m \, s^{-1}$')  #  r - значит red
pylab.xlabel('LP (mW)')
pylab.ylabel('$E_r$ (GPa)')
pylab.title('V = 180 $\mu m \, s^{-1}$')
pylab.legend(loc='upper right')
pylab.subplot(122)
for k in range(len(frame)):
    lab = (str(list_LP[k])+'mW')
    pylab.plot(frame[k][:,0], frame[k][:,1], label = lab)
pylab.xlabel('h (nm)')
pylab.ylabel('$F$ ($\mu \mathrm{N}$)')
pylab.title('Кривые нагрузки/разгрузки')
pylab.legend(loc='upper left')
pylab.subplots_adjust(wspace=0.5, hspace=0)
#Er_LP, F_h_180mkmps_Lines = plt.subplots(nrows=1, ncols=2)
#pylab.show()
path = os.path.join(path_fig,'Results_180mkmps_Lines_ser_3.pdf')
pylab.savefig(path)
#pylab.savefig('Results_180mkmps_Lines_ser_1.png',format="png")

# %%
print(Er_LP)
np.save("Er_180mkms_Lines_ser_3",Er_LP)
# Out:
# [[ 8.5         9.5        10.5       ]
#  [ 0.21859925  0.16447884  0.15490194]]

# %%
sample_list
# Out:
# ['LP17_3ser_3B', 'LP19_3ser_3B', 'LP21_3ser_3B']
