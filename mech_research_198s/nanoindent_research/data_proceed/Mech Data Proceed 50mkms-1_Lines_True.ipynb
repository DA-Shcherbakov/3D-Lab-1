# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
from io import StringIO
import math
import os
plt.close('all')

LP21_1F = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Forward_2021-11-25T10-59-50-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
LP21_2R = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Relax_2021-11-25T10-59-50-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
LP21_3B = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Backward_2021-11-25T10-59-50-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')

LP19_1F = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Forward_2021-11-25T11-04-27-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
LP19_2R = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Relax_2021-11-25T11-04-27-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
LP19_3B = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Backward_2021-11-25T11-04-27-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')

# LP17_1F = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Forward_2021-11-25T11-08-56-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
# LP17_2R = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Relax_2021-11-25T11-08-56-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
# LP17_3B = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Backward_2021-11-25T11-08-56-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')

LP15_1F = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Forward_2021-11-25T11-13-26-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
LP15_2R = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Relax_2021-11-25T11-13-26-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
LP15_3B = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Backward_2021-11-25T11-13-26-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')

LP13_1F = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Forward_2021-11-25T11-17-56-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
LP13_2R = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Relax_2021-11-25T11-17-56-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
LP13_3B = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Backward_2021-11-25T11-17-56-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')

# LP11_1F = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Forward_2021-11-25T11-22-28-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
# LP11_2R = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Relax_2021-11-25T11-22-28-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
# LP11_3B = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Backward_2021-11-25T11-22-28-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')

# LP9_1F = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Forward_2021-11-25T11-27-00-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
# LP9_2R = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Relax_2021-11-25T11-27-00-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
# LP9_3B = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Backward_2021-11-25T11-27-00-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')

# LP7_1F = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Forward_2021-11-25T11-31-29-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
# LP7_2R = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Relax_2021-11-25T11-31-29-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')
# LP7_3B = np.loadtxt("Move_clbr_flat_punch_Lines_50mkmps(True)_1_series/Backward_2021-11-25T11-31-29-LP21-7_Lines_50mkmps(True)_1_series.data.txt",delimiter='\t')

# %%
tmp = %who_ls
i = 0
sample_list_tmp = []
while tmp[i][0] == 'L':
    sample_list_tmp.append(tmp[i])
    i+=1
# %whos
sample_list = sample_list_tmp [2::3]
print(sample_list)

f = open('path.txt','r')
path_fig = f.readline().strip()
f.close()

f = open('config_proceed.txt','r')
dS_modale = int(f.readline().strip())
f.close()
sample_list
# Out:
# Variable          Type       Data/Info
# --------------------------------------
# LP13_1F           ndarray    9267x2: 18534 elems, type `float64`, 148272 bytes (144.796875 kb)
# LP13_2R           ndarray    926x2: 1852 elems, type `float64`, 14816 bytes
# LP13_3B           ndarray    7169x2: 14338 elems, type `float64`, 114704 bytes (112.015625 kb)
# LP15_1F           ndarray    9300x2: 18600 elems, type `float64`, 148800 bytes (145.3125 kb)
# LP15_2R           ndarray    926x2: 1852 elems, type `float64`, 14816 bytes
# LP15_3B           ndarray    6983x2: 13966 elems, type `float64`, 111728 bytes (109.109375 kb)
# LP19_1F           ndarray    9269x2: 18538 elems, type `float64`, 148304 bytes (144.828125 kb)
# LP19_2R           ndarray    926x2: 1852 elems, type `float64`, 14816 bytes
# LP19_3B           ndarray    6990x2: 13980 elems, type `float64`, 111840 bytes (109.21875 kb)
# LP21_1F           ndarray    9427x2: 18854 elems, type `float64`, 150832 bytes (147.296875 kb)
# ...

# %%
for name in sample_list_tmp:
    np_tmp = globals().get(name)
    if name[-1] !='B':

    #     print(np_tmp[:,0])
        plt.plot(np_tmp[:,0],np_tmp[:,1])
    else:
        plt.plot(np_tmp[:,0],np_tmp[:,1])
        plt.title(name[:-3])
        plt.show()
#plt.legend()

# %%
def find_limit(np_tmp):
    down_limit =0
#     up_limit = 0
    count_d = 0
#     count_up = 0
    
    df_limit = 0.3
    step = 30
#     step_dt = 0.2
    i = 1
    len_np_tmp = len(np_tmp)
#     print(np_tmp)
#     print('h,nm',(np_tmp[i,0], np_tmp[2,0]),' F,mkmN',(np_tmp[i,1],np_tmp[i+step,1]))
    while i < len_np_tmp/2:
        
        i_new = i + step
    
#         print('h,nm',(np_tmp[i,0], np_tmp[i_new,0]),' F,mkmN',(np_tmp[i,1],np_tmp[i_new,1]))
        
        df_d = (np_tmp[i,1] - np_tmp[i_new,1])/(np_tmp[i,0] - np_tmp[i_new,0])

#         df_up = (np_tmp[-i][1] - np_tmp[-(i_new)][1])/(np_tmp[-i][0] - np_tmp[-(i_new)][0])
        
#         print(df_d,df_up)

        if abs(df_d) < df_limit and count_d < 10:
            down_limit = i
            count_d = 0
        else:
            count_d += 1

#         if abs(df_up) < df_limit and count_up < 10:
#             up_limit = i
#             count_up = 0
#         else:
#             count_up += 1
              
        i+=step
#     up_limit_tmp = -up_limit
#     print(down_limit,np_tmp[down_limit,0])
#     counter = 0
    if down_limit != 0:
        for i in range(down_limit):
            np_tmp = np.delete(np_tmp,(0), axis = 0)
#             counter +=1
#     print('I have deleted that %d!'%(counter))
        
    len_np_tmp -= down_limit 
    
#     if up_limit != 0:
#         for i in range(up_limit):
#             np_tmp = np.delete(np_tmp,(-1), axis = 0)
    
    #print(len(DF),down_limit,up_limit)
    
    
    
    
    #len_DF = len(DF)
    #df_limit = 10000
    #down_limit =0
    #up_limit = 0
    #count_up = 0
    #count_d = 0
    #i = 0
    #part = 0.35
    #while i < len_DF*part:
    
        #df_d = (DF[i][3] - DF[i_new][3])/

        #df_up = (DF[-i][3] - DF[-(i_new)][3])/
        
   #     if (DF[i][3] - DF[i_new][3])==0:
             #down_limit = i
     #       count_d = 0
        #elif abs((DF[i][2] - DF[i_new][2])/(DF[i][3] - DF[i_new][3])) > df_limit and count_d < 10:
         #   print((DF[i][2] - DF[i_new][2])/(DF[i][3] - DF[i_new][3]))
          #  down_limit = i
           # count_d = 0
        #else:
         #   count_d += 1

#        if (DF[-i][3] - DF[-(i_new)][3])==0:
#            up_limit = i
#            count_up = 0
#        elif abs((DF[-i][2] - DF[-(i_new)][2])/(DF[-i][3] - DF[-(i_new)][3])) > df_limit and count_up < 10:
#            print((DF[-i][2] - DF[-(i_new)][2])/(DF[i][3] - DF[-(i_new)][3]))
#            up_limit = i
#            count_up = 0
#        else:
#            count_up += 1
              
#        i+=step
    
#    for i in range(down_limit):
#        DF = np_tmp.delete(DF,(0), axis = 0)
        
#    len_DF -= down_limit 
    
#    for i in range(up_limit):
#        DF = np_tmp.delete(DF,(-1), axis = 0)
        
#    print(len(DF),down_limit,up_limit)
#    print(DF.shape)
    return np_tmp

# %%
def join_data(frame):
#     print(id(np.empty((1,2))))
    new_np_tmp = np.zeros((1,2))
#     print(id(new_np_tmp),new_np_tmp)
    for name in sample_list_tmp:
        
        np_tmp = globals().get(name)
#         print(name,id(np_tmp))
#         new_np_tmp = np_tmp.copy()
        if name[-1] != 'B':

            new_np_tmp = np.vstack((new_np_tmp,np_tmp))
#             print('new_np_tmp',id(new_np_tmp),len(new_np_tmp))
        #i = 1
        #dlina = len(DF_tmp)
        #while i < dlina:
        #    new_DF_tmp = np.vstack([new_DF_tmp, DF_tmp[]])
#            i+=1000
        
        #new_DF_tmp.rename(columns = {'F,mkmN': name}, inplace = True)
        else:
            new_np_tmp = np.vstack((new_np_tmp,np_tmp))
            frame.append(new_np_tmp)
#             print('new_np_tmp',id(new_np_tmp),len(new_np_tmp))
            new_np_tmp = new_np_tmp[0:0,:]
#         print('new_np_tmp',id(new_np_tmp),new_np_tmp)

# %%
frame = []

join_data(frame)

# %%
for k in range(len(frame)):
    np_tmp = frame[k]
    #DF_tmp_df = pd.DataFrame(data=DF_tmp, index=np.array(range(len(DF_tmp))),columns=range(5))
    #DF_tmp_df.plot(x=0,y=3)
#     print(np_tmp.shape,id(np_tmp),np_tmp[0,0])
    frame[k] = find_limit(np_tmp)
    min_value = frame[k][0,0]
    print(min_value)
    frame[k][:,0] = frame[k][:,0] - min_value
    plt.plot(frame[k][:,0],frame[k][:,1],label = sample_list_tmp[3*k][:4])
plt.legend()
plt.ylabel('F ($\mu$m)')
plt.xlabel('h (nm)')
path = os.path.join(path_fig,'F_h_50mkmps_Lines_True.pdf')
plt.savefig(path)

plt.show()
# Out:
# 0.0
# 0.0
# 0.0
# 302.22265625

# %%
# %who_ls
# Out:
# ['LP13_1F',
#  'LP13_2R',
#  'LP13_3B',
#  'LP15_1F',
#  'LP15_2R',
#  'LP15_3B',
#  'LP19_1F',
#  'LP19_2R',
#  'LP19_3B',
#  'LP21_1F',
#  'LP21_2R',
#  'LP21_3B',
#  'StringIO',
#  'dS_modale',
#  'f',
#  'find_limit',
#  'frame',
#  'i',
#  'join_data',
#  'k',
#  'math',
#  'min_value',
#  'name',
#  'np',
#  'np_tmp',
#  'os',
#  'path',
#  'path_fig',
#  'pd',
#  'plt',
#  'sample_list',
#  'sample_list_tmp',
#  'sns',
#  'tmp']

# %%
def reader_of_LP(sample_list):
    list_LP = []
    for name in sample_list:
        len_name = len(name)
        str_list = list(name)
        str_tmp = []
        i = 0
        j = 0
        while name[i] !='P':
            i+=1
        i+=1
        while name[i+j] !="_":
            str_tmp +=str_list[i+j]
            j+=1
            
        tmp = int(''.join(str_tmp))
        if tmp < 30:
            tmp = float(tmp/2)
        else:
            tmp = float(tmp/100/2)
            
        list_LP.append(tmp)
    return list_LP

# %%
list_LP = reader_of_LP(sample_list)
list_LP
# Out:
# [6.5, 7.5, 9.5, 10.5]

# %%
def calc_Er(np_tmp,dS_modale):
    
#     name = sample_list[k]
#     print(np_tmp,name)
#     normirovka(np_tmp,name)
    start = 0
    #print(start,np_tmp['h,nm'][start])
    finish = start
    #print(start,np_tmp['h,nm'][finish+1])
    dS_real = 0 
    #print(start)
    while abs(dS_real) < dS_modale:
        
        finish +=1
        dS_real = np_tmp[finish][0] - np_tmp[start][0]
        #print(dS_real)
    
    NP = np.array([0,0])
    for i in range(start,finish+1):
        #print([np_tmp['h,nm'][i], np_tmp[sample_list[k]][i]])
        NP = np.vstack([NP, np_tmp[i]])
    NP = np.delete(NP,(0),axis = 0)
    #print(np_tmp[:,0])
    plt.plot(NP[:,0], NP[:,1])
    
    x_tmp = np.vstack([NP[:,0], np.ones(len(NP[:,0]))]).T
    #x_tmp = np_tmp[:,0].T
    #print(x_tmp)
    Er, tmp =np.linalg.lstsq(x_tmp,NP[:,1],rcond=None)[0] 

    plt.plot(x_tmp,x_tmp*Er + tmp,'r',label="Fitted line")
#     plt.xlim([2000-dS_modale, 2050])
    plt.ylim([0,20000])
    #Er = (np_tmp[sample_list[k]][finish] - np_tmp[sample_list[k]][start])/(dS_real)
    #np_tmp[start-50:finish].plot(x='h,nm',y=sample_list[k])
    #print(Er)
    return abs(Er)
    
# def find_reload(np_tmp):
    
#     len_np_tmp = len(np_tmp)
#     i = int(len_np_tmp*0.2)
#     step = 1
#     np_tmp_limit = 15
#     count = 0
#     #print(i,np_tmp['h,nm'])
#     np_tmp = int((np_tmp['h,nm'][5+i] - np_tmp['h,nm'][i])/(np_tmp['t,s'][i+5] - np_tmp['t,s'][i]))
#     #print(np_tmp)
#     while i < len_np_tmp :
#         i+=step
#         np_tmp = int((np_tmp['h,nm'][i+5] - np_tmp['h,nm'][i])/(np_tmp['t,s'][i+5] - np_tmp['t,s'][i]))
#         #print(np_tmp,count,i)
#         if np_tmp >= 0 and count < 3:
#             count = 0
#         elif count >= 3 and abs(np_tmp) > np_tmp_limit:
#             #print(i)
#             return i
#         else:
#             count+=1
#         #print(np_tmp)
        
#     #print(i)
#     #print(np_tmp)
#     #np_tmp.plot(x='t,s',y='h,nm')
#     #return i
    
# def normirovka(np_tmp,name):
    
#     j = 0
#     ref_tmp = min(np_tmp[name][:len(np_tmp)-1])
#     while j < len(np_tmp):


#         tmp = np_tmp[name][j]
#         np_tmp[name][j] = tmp - ref_tmp
#         j+=1

# %%
list_Er = []
for name in sample_list:
    np_tmp = globals().get(name)
    df_dh = calc_Er(np_tmp,dS_modale)
    Area = 625 *0.25 * math.pi
    t = 10
    Er = t*df_dh/Area
    list_Er.append(Er)
    #calc_Er(DF_tmp,k)
list_Er
# Out:
# [0.7760716099616308,
#  0.5700108700796381,
#  0.5577203101431202,
#  0.23227536951179753]

# %%
import pylab
Er_LP = np.vstack((list_LP, list_Er))
pylab.subplot(121)
pylab.scatter(Er_LP[0], Er_LP[1], label= 'V = 50 $\mu m \, s^{-1}$')  #  r - значит red
pylab.xlabel('LP (mW)')
pylab.ylabel('$E_r$ (GPa)')
pylab.title('V = 50 $\mu m \, s^{-1}$')
# pylab.legend(loc='upper right')
pylab.subplot(122)
for k in range(len(frame)):
    lab = (str(list_LP[k])+'mW')
    pylab.plot(frame[k][:,0], frame[k][:,1], label = lab)
pylab.xlabel('h (nm)')
pylab.ylabel('$F$ ($\mu \mathrm{N}$)')
pylab.title('Кривые нагрузки/разгрузки')
pylab.legend(loc='upper left')
pylab.subplots_adjust(wspace=0.5, hspace=0)
#Er_LP, F_h_180mkmps_Lines = plt.subplots(nrows=1, ncols=2)
#pylab.show()
path = os.path.join(path_fig,'Results_50mkmps_Lines_True.pdf')
pylab.savefig(path)
#pylab.savefig('Results_180mkmps_Lines_ser_1.png',format="png")

# %%
print(Er_LP)
np.save("Er_50mkms-1_Lines(True)",Er_LP)
# Out:
# [[ 6.5         7.5         9.5        10.5       ]
#  [ 0.77607161  0.57001087  0.55772031  0.23227537]]

# %%
sample_list
# Out:
# ['LP13_3B', 'LP15_3B', 'LP19_3B', 'LP21_3B']
